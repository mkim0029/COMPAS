# %%
! pip install numpy h5py pandas
# Out:
# Requirement already satisfied: numpy in c:\users\minji\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: h5py in c:\users\minji\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: pandas in c:\users\minji\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\minji\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\minji\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\minji\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import os, sys    # for handling paths
import h5py as h5  #for handling data format
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
def restrict(df, col, lower_limit, upper_limit):
    mask = (df[col] >= lower_limit) & (df[col] <= upper_limit)
    return df[mask]

# %% [markdown]
# Inspect the data:
# Data_SSE  = h5.File('COMPAS_Output_SSE.h5')
# list(Data_SSE.keys())
#
# Inspect mergers:
# CE_BSE = Data_BSE['BSE_Common_Envelopes']
# #list(CE_BSE.keys())
# merger = CE_BSE['Merger'][()]
# print(merger.shape)
#
# Print log file keys (e.g. system parameter keys):
# list(SP_BSE.keys())

# %% [markdown]
# Finding the unit of a parameter:
# print(SP_BSE['Teff(1)'].attrs['units'])
# print(SP_BSE['Luminosity(1)'].attrs['units'])

# %%
df1 = pd.read_csv('BSE_Detailed_Output_0.csv', sep = ',', header = 2)
df2 = pd.read_csv('SSE_Detailed_Output_0.csv', sep = ',', header = 2)

# %%
df1 = restrict(df1, 'Stellar_Type(1)', 0, 1) #MS stars only
df1 = restrict(df1, 'Stellar_Type(2)', 15, 15) 
df2 = restrict(df2, 'Stellar_Type', 0, 1) #MS stars only

# %%
plt.figure(figsize=(7,6))
plt.scatter(df1['        Teff(1)         '], df1['     Luminosity(1)      '], s = 0.5, label = 'merger')
plt.scatter(df2['          Teff          '], df2['       Luminosity       '], s = 0.5, label = 'single')
plt.xlabel('Effective Temperature (K)')
plt.ylabel('Luminosity (Lsun)')
plt.gca().invert_xaxis()
plt.yscale('log')
plt.title('Merger product (7Msun + 1Msun) vs Single star')
#plt.ylim((1e1,4e1))
plt.legend(loc = 'lower right')

# %%
plt.scatter(df1['         Age(1)         '], df1['        Mass(1)         '], s = 0.5, label = 'merger')
plt.scatter(df2['          Age           '], df2['          Mass          '], s = 0.5, label = 'single')
plt.xlabel('Age (Myr)')
plt.ylabel('Mass (Msun)')
plt.title('Merger product vs Single star')
plt.ticklabel_format(useOffset=False)
plt.legend()
